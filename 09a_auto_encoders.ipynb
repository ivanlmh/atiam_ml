# %% [markdown]
# # Generative models - auto-encoders
#
# ### Author: Philippe Esling (esling@ircam.fr)

# %% [markdown]
# In this course we will cover
# 1. A brief introduction to [generative models](#generative)
# 2. A formal presentation of [Auto-Encoders](#ae) (AEs)
# 3. An explanation of how to [implement AEs](#implement)
# 4. An [application](#application) of AEs for modeling images
# 4. An practical exemple of [convolutional denoising AEs](#denoising) for image data **(exercise)**

# %% [markdown]
# <a id="generative"></a>
#
# ## Generative models
#
# ### Supervised refresher
#
# Until now, we have mostly discussed models that are developed for _supervised_ and _discriminative_ tasks. To formalize this problem, we have a set of data $\{\mathbf{x}_{i}, \mathbf{y}_{i}\}_{i\in[1,n]}$, where the $\mathbf{x}_{i}$ and $\mathbf{y}_{i}$ are linked. Therefore, we want to approximate this relation through
# \begin{equation}
#     \mathbf{\hat{y}} = \mathcal{F}_\mathbf{\theta}(\mathbf{x})
# \end{equation}
# where we train the parameters $\mathbf{\theta}$ so that $\mathbf{\hat{y}}\approx\mathbf{y}$. The existence of a label $\mathbf{y}$ ("correct answer") defines a _supervised_ problem

# %% [markdown]
# ### Going unsupervised
#
# In some cases, we might only have a set of data $\{\mathbf{x}_{i}\}_{i\in[1,n]}$, and still be interested in learning some underlying properties or structure of this set. In that case, the problem is _unsupervised_ as we have to learn without a given answer.
#
# Here, we can turn to _generative_ models [[1](#reference1)], which allows to create new data instances based on the observation of existing examples. Although these models are more naturally defined in a _probabilistic way_, we will assume that we have some simple _code_ $\mathbf{z}$, which allows to control the properties of the generation, and need to learn
# \begin{equation}
#     \mathbf{\hat{x}} = \mathcal{F}_\mathbf{\theta}(\mathbf{z})
# \end{equation}
# where we still need to learn $\mathbf{\theta}$, so that $\mathbf{\hat{x}}$ have similar properties to that of the examples in $\{\mathbf{x}_{i}\}_{i\in[1,n]}$.
#
# Now the problem to solve is how we can learn directly from a set of data.

# %% [markdown]
# <a id="ae"></a>
#
# ## Auto-encoders
#
# One way to understand a set of data is to try to _compress_, or _simplify_ the corresponding dataset. So the idea is to learn simultaneously how to _encode_ our unlabeled input $\{\mathbf{x}_{i}\}_{i\in[1,n]}$ and to _decode_ the corresponding representation. This idea give rise to the notion of **auto-encoder**.
#
# ### Architecture
#
# The auto-encoder is an unsupervised architecture originally proposed to perform _dimensionality reduction_ [[3](#reference3)]. As its name indicates, we will try to train this model to learn an efficient _encoding_ $\mathbf{z}$ of unlabeled input data $\mathbf{x}$. The only way to learn efficient parameters is to also learn a _decoding_ function to _reconstruct_ $\mathbf{x}$ from $\mathbf{z}$.
#
# <img src="images/auto_encoder.png"/>
#
# As shown here, a first model $\mathcal{E}_\phi$ _encodes_ the input into a _latent code_ $\mathbf{z}$ in order to provide a low-dimensional representation of the data. A second model $\mathcal{D}_\theta$ designated as the _decoder_ aims to generate outputs from $\mathbf{z}$ that are as close to the original inputs as possible.

# %% [markdown]
# ### Formal definition
#
# The latent code $\mathbf{z}$ can be seen as a compressed abstract representation, and may be used as an intermediate space for analysis or generation. This helps to govern the distribution of the data through a simpler and higher-level representation, while enhancing the _expressiveness_ of the generative model.
# The behaviour of an auto-encoder can be formalized as:
#
# $$
# \begin{align}
# \mathbf{z} &= \mathcal{E}_\phi(\mathbf{x}) \\
# \mathbf{\hat{x}} &= \mathcal{D}_\theta(\mathbf{z})
# \end{align}
# $$
#
# with the _encoder_ $\mathcal{E}_\phi$ and _decoder_ $\mathcal{D}_\theta$ functions parameterized respectively by $\phi$ and $\theta$. As we can see this defines the reconstruction relationship
# $$
#     \mathbf{\hat{x}} = \mathcal{D}_\theta(\mathcal{E}_\phi(\mathbf{x}))
# $$

# %% [markdown]
# ### Training
#
# The training of an auto-encoder consists in finding the optimal functions of encoding $\mathcal{E}^*$ and decoding $\mathcal{D}^*$ by evaluating the \textit{reconstruction error} $\mathcal{L}$ between $\mathbf{x}$ and $\mathbf{\hat{x}}$, such that
# \begin{equation}
#     \mathcal{E}^*, \mathcal{D}^* = arg\,min_{ \phi, \theta}{\mathcal{L}}(\mathbf{x}, \mathcal{D}_\theta(\mathcal{E}_\phi(\mathbf{x})))
# \end{equation}
#
# As the latent space usually has a smaller dimensionality than the input, it acts as an incentive for the network to find the main attributes of variations in the dataset (and also explains its use for _dimensionality reduction_).

# %% [markdown]
# ### Variants and discussion
#
# There are several variants of auto-encoders, such as denoising auto-encoders or variational auto-encoders. Each address some downside of the basic AE model. For instance, the deterministic nature of the basic auto-encoder implies a point-wise mapping of the latent space, meaning that not all the latent positions can be leveraged to produce relevant reconstructions. Because of this reason, there is no way to ensure that the latent space could allow a robust generalization and that any random $\mathbf{z}$ would generate a meaningful output.

# %% [markdown]
# <a id="implement"> </a>
#
# ## Implementation
#
# Here, we discuss how we can implement and train a simple auto-encoder network in Pytorch. As discussed earlier, an AE is composed of two parts, an **encoder** and a **decoder**. The goal of the encoder is to "compress" the dataset, representing its principal features with a very small code, while the goal of the decoder is to learn how to reproduce the initial input from this code. Hence, we will first need to use some basic imports and definition to setup our problem

# %% [markdown]
# ### Import Pytorch and other libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torchvision
# from helper_plot import hdr_plot_style
# hdr_plot_style();

# %% [markdown]
# ### Load the dataset
#
# To start with a pragmatic and simple to understand example, we  will try to train the basic AE using the Fashion MNIST dataset. This dataset contains images of size 28x28 pixels, with different pieces of clothing. The following code allows to load (and eventually download) the dataset, by using the `torchvision.datasets` module. We also plot some randomly selected test examples

# %%
import matplotlib
dataset_dir = './data'
# Going to use 80%/20% split for train/valid
valid_ratio = 0.2
# Load the dataset for the training/validation sets
train_valid_dataset = torchvision.datasets.FashionMNIST(root=dataset_dir, train=True, transform=torchvision.transforms.ToTensor(), download=True)
# Split it into training and validation sets
nb_train = int((1.0 - valid_ratio) * len(train_valid_dataset))
nb_valid =  int(valid_ratio * len(train_valid_dataset))
train_dataset, valid_dataset = torch.utils.data.dataset.random_split(train_valid_dataset, [nb_train, nb_valid])
# Load the test set
test_dataset = torchvision.datasets.FashionMNIST(root=dataset_dir, transform=torchvision.transforms.ToTensor(),train=False)
# Prepare 
num_threads = 4     # Loading the dataset is using 4 CPU threads
batch_size  = 128   # Using minibatches of 128 samples
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, num_workers=num_threads)
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=False, num_workers=num_threads)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=False,num_workers=num_threads)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# Here, we are going to check the properties of our different sets and also plot some random examples, in order to better understand what type of data we will be working with.

# %%
print("The train set contains {} images, in {} batches".format(len(train_loader.dataset), len(train_loader)))
print("The validation set contains {} images, in {} batches".format(len(valid_loader.dataset), len(valid_loader)))
print("The test set contains {} images, in {} batches".format(len(test_loader.dataset), len(test_loader)))
nsamples = 10
classes_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal','Shirt', 'Sneaker', 'Bag', 'Ankle boot']
imgs_test, labels = next(iter(train_loader))
fig = plt.figure(figsize=(20,5))
for i in range(nsamples):
    ax = plt.subplot(1,nsamples, i+1)
    plt.imshow(imgs_test[i, 0, :, :], vmin=0, vmax=1.0, cmap=matplotlib.cm.gray)
    ax.set_title("{}".format(classes_names[labels[i]]), fontsize=15)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# The train set contains 48000 images, in 375 batches
# The validation set contains 12000 images, in 94 batches
# The test set contains 10000 images, in 79 batches

# %% [markdown]
# ## Basic auto-encoder
#
# We recall here that in order to define an autoencoder, we will need an `encoder`, which compresses the images into a small latent vector, and a `decoder`, that reconstructs the original image from this code. Here, we will start very basic and define the encoder and decoder as simple `Dense` layers. To define the model simply, we will use the [Keras API](https://www.tensorflow.org/guide/keras/custom_layers_and_models) defined in the `tensorflow.keras` module (Note that we pre-loaded the `layers` submodule

# %%
class AE(nn.Module):
    def __init__(self, encoding_dim):
        super(AE, self).__init__()
        self.latent_dim = encoding_dim
        self.hidden_dim = 256
        self.encoder = nn.Sequential(
          nn.Linear(28 * 28, self.hidden_dim), nn.ReLU(),
          nn.Linear(self.hidden_dim, self.hidden_dim), nn.ReLU(),
          nn.Linear(self.hidden_dim, self.latent_dim), nn.Sigmoid()
        )
        self.decoder = nn.Sequential(
          nn.Linear(self.latent_dim, self.hidden_dim), nn.ReLU(),
          nn.Linear(self.hidden_dim, self.hidden_dim), nn.ReLU(),
          nn.Linear(self.hidden_dim, 28 * 28), nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x.reshape(-1, 28 * 28))
        decoded = self.decoder(encoded)
        return decoded.reshape(-1, 1, 28, 28)

# %% [markdown]
# Here we can see that the model depends on a given `encoding_dim` variable, which defines the size of the latent code. Therefore, we can instantiate our model arbitrarliy with `64` dimensions

# %%
latent_dim = 64   
model = AE(latent_dim)

# %% [markdown]
# The only remaining part that we did not discuss yet is what type of _loss_ (defined as $\mathcal{L}$) we can use to train our model. First, we will simply rely on the _Mean Squared Error_ (MSE) loss, which is defined as
# \begin{equation}
#     \mathcal{L}_{MSE}(\hat{\mathbf{x}}, \mathbf{x}) = \mid \hat{\mathbf{x}}, \mathbf{x} \mid^{2}
# \end{equation}

# %%
# Loss function that we will use
loss_fn = torch.nn.MSELoss(reduction='sum')

# %%
device = ''
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# <a id="application"> </a>
#
# ### Training the model
#
# Train the model using `x_train` as both the input and the target. The `encoder` will learn to compress the dataset from 784 dimensions to the latent space, and the `decoder` will learn to reconstruct the original images.
# .

# %%
# Learning rate
learning_rate = 1e-4
# Optimizer to fit the weights of the network
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
model = model.to(device)
for t in range(20):
    full_loss = torch.Tensor([0])
    # Forward pass: compute predicted y by passing x to the model.
    for i, (x, _) in enumerate(train_loader):
        x = x.to(device)
        y_pred = model(x).to(device)
        # Compute the loss.
        loss = loss_fn(y_pred, x)
        # Before the backward pass, zero all of the network gradients
        optimizer.zero_grad()
        # Backward pass: compute gradient of the loss with respect to parameters
        loss.backward()
        # Calling the step function to update the parameters
        optimizer.step()
    print(loss)
# Out:
# tensor(5680.7598, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4460.5786, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3974.5330, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3577.4902, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3081.6150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2807.8318, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2794.8882, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2663.2073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2776.7927, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2584.3782, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2477.5825, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2433.3025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2266.6987, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2202.8228, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2183.1167, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2276.7000, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2143.4067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2033.3009, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2042.3350, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1978.6263, device='cuda:0', grad_fn=<MseLossBackward0>)

# %% [markdown]
# Now that the model is trained, we can test it by encoding and decoding images from the test set.

# %%
imgs_test = imgs_test.to(device)
encoded_imgs = model.encoder(imgs_test.reshape(-1,28*28)).to(device)
decoded_imgs = model.decoder(encoded_imgs).reshape(-1,28,28).detach().cpu().numpy()

# %% [markdown]
# By plotting the images, we can see that the model is able to perform an adequate (yet somewhat blurry) reconstruction of the input images. The interesting point is that this reconstruction comes from a code of only `64` dimensions, whereas the original images have `784` dimensions.

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(imgs_test[i, 0].cpu())
    plt.title("original"); plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    plt.title("reconstructed"); plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ### Improvements
#
# Even though this very basic example seems to work, several improvements can be made over the original model. First, we can see that the overall framework does not depend on the exact nature of the `encoder` and `decoder`.
#
# ***
# 1. We rewrite the original class to accept any type of architecture for these (see code below).
# 2. Fill the missing code to have a new AE model
# ***

# %%
class AE(nn.Module):
    def __init__(self, encoder, decoder, encoding_dim):
        super(AE, self).__init__()
        self.latent_dim = encoding_dim
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, x):
        encoded = self.encoder(x.reshape(-1, 28 * 28))
        decoded = self.decoder(encoded)
        return decoded.reshape(-1, 1, 28, 28)

######################
# choice of layers done following geeksforgeeks.org tutorial for AE on MNIST 
encoder = torch.nn.Sequential(
            torch.nn.Linear(28 * 28, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 36),
            torch.nn.ReLU(),
            torch.nn.Linear(36, 18),
            torch.nn.ReLU(),
            torch.nn.Linear(18, 9)
        )
decoder = torch.nn.Sequential(
            torch.nn.Linear(9, 18),
            torch.nn.ReLU(),
            torch.nn.Linear(18, 36),
            torch.nn.ReLU(),
            torch.nn.Linear(36, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 28 * 28),
            torch.nn.Sigmoid()
        )
model = AE(encoder, decoder, latent_dim)

######################

# %% [markdown]
# Second, we only used the train dataset, whereas the use of a validation and test sets allows to ensure that we do not overfit our model.
#
# ***
# 1. Write a separate train function, that can be called on different sets
# 2. Re-write the training loop to test overfitting
# ***

# %%
######################
def validateAE(model, validation_loader, loss_fn=torch.nn.MSELoss(reduction='sum')):
    with torch.no_grad():
        for i, (x, _) in enumerate(validation_loader):
            # forward validation set and calculate loss
            x = x.to(device)
            y_pred = model(x).to(device)
            valid_loss = loss_fn(y_pred, x)
        print("Validation loss:", valid_loss)

def trainAE(model, train_loader, num_epochs, loss_fn=torch.nn.MSELoss(reduction='sum'),
            learning_rate=1e-4, optimizer=None, validate=False, validation_loader=None):
    if not optimizer:
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    for e in range(num_epochs):
        full_loss = torch.Tensor([0])
        # Forward pass: compute predicted y by passing x to the model.
        for i, (x, _) in enumerate(train_loader):
            x = x.to(device)
            y_pred = model(x).to(device)
            # Compute the loss.
            loss = loss_fn(y_pred, x)
            # Before the backward pass, zero all of the network gradients
            optimizer.zero_grad()
            # Backward pass: compute gradient of the loss with respect to parameters
            loss.backward()
            # Calling the step function to update the parameters
            optimizer.step()
        print("Epoch:", e, "/// Train loss:", loss)
        if validate:
            validateAE(model.to(device), validation_loader)

trainAE(model.to(device), train_loader, num_epochs=30, validate=True, validation_loader=valid_loader)
######################
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 0 /// Train loss: tensor(8501.2422, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(6693.3853, device='cuda:0')
# Epoch: 1 /// Train loss: tensor(5738.0596, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(4623.7085, device='cuda:0')
# Epoch: 2 /// Train loss: tensor(4453.4565, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(3676.6323, device='cuda:0')
# Epoch: 3 /// Train loss: tensor(4098.8848, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(3368.8276, device='cuda:0')
# Epoch: 4 /// Train loss: tensor(3863.6248, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(3176.0234, device='cuda:0')
# Epoch: 5 /// Train loss: tensor(3720.0403, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(3033.9275, device='cuda:0')
# Epoch: 6 /// Train loss: tensor(3619.9365, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2918.6396, device='cuda:0')
# Epoch: 7 /// Train loss: tensor(3526.6038, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2808.6289, device='cuda:0')
# Epoch: 8 /// Train loss: tensor(3452.0095, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2731.5659, device='cuda:0')
# Epoch: 9 /// Train loss: tensor(3388.3425, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2678.3518, device='cuda:0')
# Epoch: 10 /// Train loss: tensor(3321.0315, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2621.2463, device='cuda:0')
# Epoch: 11 /// Train loss: tensor(3263.1074, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2571.9170, device='cuda:0')
# Epoch: 12 /// Train loss: tensor(3209.0400, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2528.5496, device='cuda:0')
# Epoch: 13 /// Train loss: tensor(3159.8193, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2483.7529, device='cuda:0')
# Epoch: 14 /// Train loss: tensor(3108.0444, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2436.1118, device='cuda:0')
# Epoch: 15 /// Train loss: tensor(3042.5083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2393.1147, device='cuda:0')
# Epoch: 16 /// Train loss: tensor(2986.4370, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2359.3755, device='cuda:0')
# Epoch: 17 /// Train loss: tensor(2939.1106, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2331.2056, device='cuda:0')
# Epoch: 18 /// Train loss: tensor(2900.9248, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2300.4727, device='cuda:0')
# Epoch: 19 /// Train loss: tensor(2866.9832, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2269.6699, device='cuda:0')
# Epoch: 20 /// Train loss: tensor(2834.1396, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2240.6794, device='cuda:0')
# Epoch: 21 /// Train loss: tensor(2803.1565, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2212.2759, device='cuda:0')
# Epoch: 22 /// Train loss: tensor(2769.9607, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2182.9846, device='cuda:0')
# Epoch: 23 /// Train loss: tensor(2733.4304, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2151.5508, device='cuda:0')
# Epoch: 24 /// Train loss: tensor(2696.6724, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2118.3872, device='cuda:0')
# Epoch: 25 /// Train loss: tensor(2660.6675, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2081.9521, device='cuda:0')
# Epoch: 26 /// Train loss: tensor(2621.5752, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2046.3530, device='cuda:0')
# Epoch: 27 /// Train loss: tensor(2583.8687, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2012.1384, device='cuda:0')
# Epoch: 28 /// Train loss: tensor(2547.1685, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(1980.5967, device='cuda:0')
# Epoch: 29 /// Train loss: tensor(2513.4526, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(1954.0337, device='cuda:0')

# %% [markdown]
# ## Exercise: Denoising AE
#
# Imagine (for the sake of argument), that we choose an encoding dimension which is of same dimensionality as the input one. Then, one huge problem is that nothing prevents the AE from simply learning the _identity_ function (try to imagine why). An autoencoder can also be trained to remove noise from images. This type of _regularization_ prevents the model from learning this degenerate situation.
#
# In this exercise, you will need to create your own denoising AE, by relying on a noisy version of the Fashion MNIST dataset (adding random Gaussian noise to each image). You will then train an autoencoder using the noisy image as input, and the original image as the target.
#
# Let's reimport the dataset to omit the modifications made earlier.

# %%
class GaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean
        
    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean
    
    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

# %% [markdown]
# Here, we create two new train and test sets by adding random noise to the images

# %%
# Load the datasets and use our Gaussian noise transform
train_valid_dataset = torchvision.datasets.FashionMNIST(root=dataset_dir, train=True, transform=torchvision.transforms.Compose([torchvision.transforms.ToTensor(), GaussianNoise(0., 0.1)]), download=True)
train_dataset, valid_dataset = torch.utils.data.dataset.random_split(train_valid_dataset, [nb_train, nb_valid])
test_dataset = torchvision.datasets.FashionMNIST(root=dataset_dir, transform=torchvision.transforms.Compose([torchvision.transforms.ToTensor(), GaussianNoise(0., 0.1)]),train=False)
# Create loaders
train_loader_noisy = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, num_workers=num_threads)
valid_loader_noisy = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=False, num_workers=num_threads)
test_loader_noisy = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=False,num_workers=num_threads)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# Plot the noisy images.

# %%
x_test, labels = next(iter(test_loader))
x_test_noisy, labels = next(iter(test_loader_noisy))
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.title("original")
    plt.imshow(x_test[i].squeeze())
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.gray()
    ax = plt.subplot(2, n, i + 1 + n)
    plt.title("original + noise")
    plt.imshow(x_test_noisy[i].squeeze())
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.gray()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Define a convolutional autoencoder

# %% [markdown]
# In this example, you will train a convolutional autoencoder using  [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) layers in the `encoder`, and [Conv2DTranspose](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose) layers in the `decoder`.

# %%
######################
class DenoisingAE(nn.Module):
    def __init__(self, encoder, decoder):
        super(DenoisingAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
    
    def forward(self, x):
        encoded = encoder(x)
        decoded = decoder(encoded)
        return decoded

# Layer configuration based on PyTorch beginer AutoEncoder tutorial
# Encoder network
encoder = nn.Sequential(
        nn.Conv2d(1, 8, 3, padding=1), 
        nn.ReLU(),
        nn.Conv2d(8, 3, 3, padding=1),
        nn.ReLU(),
        nn.Conv2d(3, 1, 3, padding=1),
        nn.ReLU()
    )
# Decoder network
decoder = nn.Sequential(
        nn.ConvTranspose2d(1, 3, 3, padding=1),
        nn.ReLU(),
        nn.ConvTranspose2d(3, 8, 3, padding=1),
        nn.ReLU(),
        nn.ConvTranspose2d(8, 1, 3, padding=1),
        nn.Tanh()
    )

autoencoder = DenoisingAE(encoder,decoder)

######################

# %% [markdown]
# Write down the full optimization loop to optimize your denoising auto-encoder

# %%
######################
trainAE(autoencoder.to(device), train_loader_noisy, num_epochs=50, validate=True, validation_loader=valid_loader_noisy)
######################
# Out:
# Epoch: 0 /// Train loss: tensor(3200.1348, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(2354.6294, device='cuda:0')
# Epoch: 1 /// Train loss: tensor(2218.0637, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(1601.3700, device='cuda:0')
# Epoch: 2 /// Train loss: tensor(1737.0016, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(1246.3179, device='cuda:0')
# Epoch: 3 /// Train loss: tensor(1456.7122, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(1028.9441, device='cuda:0')
# Epoch: 4 /// Train loss: tensor(1238.5851, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(877.0572, device='cuda:0')
# Epoch: 5 /// Train loss: tensor(967.2097, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(695.8672, device='cuda:0')
# Epoch: 6 /// Train loss: tensor(638.3607, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(462.6986, device='cuda:0')
# Epoch: 7 /// Train loss: tensor(485.8754, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(348.7542, device='cuda:0')
# Epoch: 8 /// Train loss: tensor(402.8434, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(291.1244, device='cuda:0')
# Epoch: 9 /// Train loss: tensor(364.2054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(261.5071, device='cuda:0')
# Epoch: 10 /// Train loss: tensor(332.1305, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(241.8645, device='cuda:0')
# Epoch: 11 /// Train loss: tensor(320.0869, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(225.2407, device='cuda:0')
# Epoch: 12 /// Train loss: tensor(299.0318, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(220.0283, device='cuda:0')
# Epoch: 13 /// Train loss: tensor(282.6388, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(205.1299, device='cuda:0')
# Epoch: 14 /// Train loss: tensor(273.4301, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(197.9349, device='cuda:0')
# Epoch: 15 /// Train loss: tensor(265.1904, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(192.6125, device='cuda:0')
# Epoch: 16 /// Train loss: tensor(258.8282, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(184.0690, device='cuda:0')
# Epoch: 17 /// Train loss: tensor(248.7135, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(179.2995, device='cuda:0')
# Epoch: 18 /// Train loss: tensor(246.3083, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(175.6488, device='cuda:0')
# Epoch: 19 /// Train loss: tensor(235.4920, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(165.7930, device='cuda:0')
# Epoch: 20 /// Train loss: tensor(230.5283, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(166.0655, device='cuda:0')
# Epoch: 21 /// Train loss: tensor(223.7266, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(161.9995, device='cuda:0')
# Epoch: 22 /// Train loss: tensor(217.4612, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(156.5307, device='cuda:0')
# Epoch: 23 /// Train loss: tensor(211.0938, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(155.4919, device='cuda:0')
# Epoch: 24 /// Train loss: tensor(209.1665, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(152.3226, device='cuda:0')
# Epoch: 25 /// Train loss: tensor(204.8564, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(149.7400, device='cuda:0')
# Epoch: 26 /// Train loss: tensor(203.9339, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(143.9316, device='cuda:0')
# Epoch: 27 /// Train loss: tensor(196.1287, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(142.3185, device='cuda:0')
# Epoch: 28 /// Train loss: tensor(199.6484, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(140.9537, device='cuda:0')
# Epoch: 29 /// Train loss: tensor(193.7516, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(139.1652, device='cuda:0')
# Epoch: 30 /// Train loss: tensor(189.3798, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(140.5179, device='cuda:0')
# Epoch: 31 /// Train loss: tensor(188.3976, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(134.7249, device='cuda:0')
# Epoch: 32 /// Train loss: tensor(187.7066, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(136.0115, device='cuda:0')
# Epoch: 33 /// Train loss: tensor(185.9781, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(136.8167, device='cuda:0')
# Epoch: 34 /// Train loss: tensor(185.5740, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(133.4469, device='cuda:0')
# Epoch: 35 /// Train loss: tensor(186.4163, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(131.2132, device='cuda:0')
# Epoch: 36 /// Train loss: tensor(179.7125, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(132.4051, device='cuda:0')
# Epoch: 37 /// Train loss: tensor(181.6506, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(130.3055, device='cuda:0')
# Epoch: 38 /// Train loss: tensor(180.6545, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(129.7122, device='cuda:0')
# Epoch: 39 /// Train loss: tensor(181.3451, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(131.5341, device='cuda:0')
# Epoch: 40 /// Train loss: tensor(177.0795, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(126.3076, device='cuda:0')
# Epoch: 41 /// Train loss: tensor(179.2803, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(126.3742, device='cuda:0')
# Epoch: 42 /// Train loss: tensor(174.4423, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(128.2914, device='cuda:0')
# Epoch: 43 /// Train loss: tensor(176.5481, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(125.9041, device='cuda:0')
# Epoch: 44 /// Train loss: tensor(176.9546, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(125.1759, device='cuda:0')
# Epoch: 45 /// Train loss: tensor(173.9041, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(124.8781, device='cuda:0')
# Epoch: 46 /// Train loss: tensor(174.8501, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(126.6326, device='cuda:0')
# Epoch: 47 /// Train loss: tensor(173.1387, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(126.1106, device='cuda:0')
# Epoch: 48 /// Train loss: tensor(172.7503, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(124.3097, device='cuda:0')
# Epoch: 49 /// Train loss: tensor(172.7394, device='cuda:0', grad_fn=<MseLossBackward0>)
# Validation loss: tensor(125.3183, device='cuda:0')

# %% [markdown]
# Plot both the noisy images and the denoised images produced by the autoencoder to check that your implementation is correct

# %%
######################

x_test, labels = next(iter(test_loader))
x_test_noisy, labels = next(iter(test_loader_noisy))

encoded_imgs = autoencoder.encoder(x_test_noisy.to(device))
decoded_imgs = autoencoder.decoder(encoded_imgs).detach().cpu().numpy()
encoded_imgs = encoded_imgs.detach().cpu().numpy()

n = 10
plt.figure(figsize=(20, 8))
for i in range(n):
    ax = plt.subplot(4, n, i + 1)
    plt.title("original")
    plt.imshow(x_test[i].squeeze())
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.gray()
    ax = plt.subplot(4, n, i + 1 + n)
    plt.title("original + noise")
    plt.imshow(x_test_noisy[i].squeeze())
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.gray()
    ax = plt.subplot(4, n, i + 1 + 2*n)
    plt.title("encoded")
    plt.imshow(encoded_imgs[i].squeeze())
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.gray()
    ax = plt.subplot(4, n, i + 1 + 3*n)
    plt.title("denoised")
    plt.imshow(decoded_imgs[i].squeeze())
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    plt.gray()
plt.tight_layout()
plt.show()

######################

# %% [markdown]
# ### References
#
# <a id="reference1"></a>
# [1] Rezende, Danilo Jimenez, and Shakir Mohamed. "Variational inference with normalizing flows." _arXiv preprint arXiv:1505.05770_ (2015). [link](http://arxiv.org/pdf/1505.05770)
#
# [2] Kingma, Diederik P., Tim Salimans, and Max Welling. "Improving Variational Inference with Inverse Autoregressive Flow." _arXiv preprint arXiv:1606.04934_ (2016). [link](https://arxiv.org/abs/1606.04934)
#
# [3] Kingma, D. P., & Welling, M. Auto-encoding variational bayes. arXiv preprint arXiv:1312.6114. (2013). [link](https://arxiv.org/pdf/1312.6114)
#
# [4] Rezende, D. J., Mohamed, S., & Wierstra, D. Stochastic backpropagation and approximate inference in deep generative models. arXiv preprint arXiv:1401.4082. (2014). [link](https://arxiv.org/pdf/1401.4082)
#
# [5] Gulrajani, I., Kumar, K., Ahmed, F., Taiga, A. A., Visin, F., Vazquez, D., & Courville, A. (2016). Pixelvae: A latent variable model for natural images. arXiv preprint arXiv:1611.05013. [link](https://arxiv.org/pdf/1611.05013)
#
# [6] Van den Oord, A., & Vinyals, O. (2017). Neural discrete representation learning. In NIPS 2017 (pp. 6306-6315). [link](http://papers.nips.cc/paper/7210-neural-discrete-representation-learning.pdf)
